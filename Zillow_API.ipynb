# %% [markdown]
# ## Zillow API to make a database
#
# In this tutorial we are going to use an API to get data from zillow to create a database. For the first step you will have to sign up with Zillow for an API, they will give you a ZWSID key that you will need to keeep. Once you do that you are going use the equests library to type in the address of the API to make a call. Once you do that you will get the following result:

# %%
import requests 
import urllib.parse
_ZWSID=open(r"C:\Users\sespejog\OneDrive\Data Sets\LA COUNTY DATA\Real Estate Data Mining").readline()
#_address=urllib.parse.quote_plus("5190 Ithaca Ave")
#city_zip=urllib.parse.quote_plus("Los Angeles CA 90032")
_address=urllib.parse.quote_plus("51 Exeter") #we url encode our address because that is how zillow wants us to input our data
city_zip=urllib.parse.quote_plus("Irvine CA 92612")
_params={"zws-id":_ZWSID,"address":_address,"citystatezip":city_zip}#we put our inpput parameters into a dictionary 
r= requests.get("http://www.zillow.com/webservice/GetDeepSearchResults.htm",params=_params)#Here is where python makes the request
r.content
# Out:
# b'<?xml version="1.0" encoding="utf-8"?><SearchResults:searchresults xsi:schemaLocation="http://www.zillow.com/static/xsd/SearchResults.xsd http://www.zillowstatic.com/vstatic/80d5e73/static/xsd/SearchResults.xsd" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:SearchResults="http://www.zillow.com/static/xsd/SearchResults.xsd"><request><address>51+Exeter</address><citystatezip>Irvine+CA+92612</citystatezip></request><message><text>Request successfully processed</text><code>0</code></message><response><results><result><zpid>25759925</zpid><links><homedetails>http://www.zillow.com/homedetails/51-Exeter-Irvine-CA-92612/25759925_zpid/</homedetails><graphsanddata>http://www.zillow.com/homedetails/51-Exeter-Irvine-CA-92612/25759925_zpid/#charts-and-data</graphsanddata><mapthishome>http://www.zillow.com/homes/25759925_zpid/</mapthishome><comparables>http://www.zillow.com/homes/comps/25759925_zpid/</comparables></links><address><street>51 Exeter</street><zipcode>92612</zipcode><city>Irvine</city><state>CA</state><latitude>33.65125</latitude><longitude>-117.827541</longitude></address><FIPScounty>6059</FIPScounty><useCode>Condominium</useCode><taxAssessmentYear>2018</taxAssessmentYear><taxAssessment>565656.0</taxAssessment><yearBuilt>1981</yearBuilt><finishedSqFt>1242</finishedSqFt><bathrooms>3.0</bathrooms><bedrooms>2</bedrooms><lastSoldDate>09/17/2007</lastSoldDate><lastSoldPrice currency="USD">490000</lastSoldPrice><zestimate><amount currency="USD">620429</amount><last-updated>10/26/2019</last-updated><oneWeekChange deprecated="true"></oneWeekChange><valueChange duration="30" currency="USD">-1638</valueChange><valuationRange><low currency="USD">589408</low><high currency="USD">651450</high></valuationRange><percentile>0</percentile></zestimate><localRealEstate><region name="University Town Center" id="275826" type="neighborhood"><zindexValue>532,300</zindexValue><links><overview>http://www.zillow.com/local-info/CA-Irvine/University-Town-Center/r_275826/</overview><forSaleByOwner>http://www.zillow.com/university-town-center-irvine-ca/fsbo/</forSaleByOwner><forSale>http://www.zillow.com/university-town-center-irvine-ca/</forSale></links></region></localRealEstate></result></results></response></SearchResults:searchresults><!-- H:002  T:34ms  S:1154  R:Sun Oct 27 14:13:19 PDT 2019  B:5.0.62786-master.ded4202~delivery_ready.a79bd3d -->'

# %% [markdown]
# Our response from the API is in xml format, a data structure that looks similar to html. If we want to parse it we will need to import the built in anaconda xml library. We then will create a root branch using our xml file.

# %%
import xml.etree.ElementTree as ET
root=ET.fromstring(r.content)
for child in root:
    print(child.tag, child.attrib)#we are printing out the attribute
# Out:
# request {}
# message {}
# response {}

# %% [markdown]
# The data is nested inside the last branch, so we will have to write a code to go inside each node and show us its output.

# %%
for node in root[2].iter():
    print(node.tag,"*"*10,node.text)
# Out:
# response ********** None
# results ********** None
# result ********** None
# zpid ********** 25759925
# links ********** None
# homedetails ********** http://www.zillow.com/homedetails/51-Exeter-Irvine-CA-92612/25759925_zpid/
# graphsanddata ********** http://www.zillow.com/homedetails/51-Exeter-Irvine-CA-92612/25759925_zpid/#charts-and-data
# mapthishome ********** http://www.zillow.com/homes/25759925_zpid/
# comparables ********** http://www.zillow.com/homes/comps/25759925_zpid/
# address ********** None
# street ********** 51 Exeter
# zipcode ********** 92612
# city ********** Irvine
# state ********** CA
# latitude ********** 33.65125
# longitude ********** -117.827541
# FIPScounty ********** 6059
# useCode ********** Condominium
# taxAssessmentYear ********** 2018
# taxAssessment ********** 565656.0
# yearBuilt ********** 1981
# finishedSqFt ********** 1242
# bathrooms ********** 3.0
# bedrooms ********** 2
# lastSoldDate ********** 09/17/2007
# lastSoldPrice ********** 490000
# zestimate ********** None
# amount ********** 620429
# last-updated ********** 10/26/2019
# oneWeekChange ********** None
# valueChange ********** -1638
# valuationRange ********** None
# low ********** 589408
# high ********** 651450
# percentile ********** 0
# localRealEstate ********** None
# region ********** None
# zindexValue ********** 532,300
# links ********** None
# overview ********** http://www.zillow.com/local-info/CA-Irvine/University-Town-Center/r_275826/
# forSaleByOwner ********** http://www.zillow.com/university-town-center-irvine-ca/fsbo/
# forSale ********** http://www.zillow.com/university-town-center-irvine-ca/

# %% [markdown]
# ### How would a bad response look like?
#
# It is important to know how a bad request looks back so when we merge our data we don't get any unexpected errors. Let's try inputing a ficticious error in our API and see what it gives us.

# %%
_address=urllib.parse.quote_plus("51 Exeturd") #we url encode our address because that is how zillow wants us to input our data
city_zip=urllib.parse.quote_plus("Irvine CA 92612")
_params={"zws-id":_ZWSID,"address":_address,"citystatezip":city_zip}#we put our inpput parameters into a dictionary 
r= requests.get("http://www.zillow.com/webservice/GetDeepSearchResults.htm",params=_params)#Here is where python makes the request
root=ET.fromstring(r.content)
for node in root[1].iter():
    print(repr(node.tag),node.text)
# Out:
# 'message' None
# 'text' Error: no exact match found for input address
# 'code' 508

# %% [markdown]
# Now that we now how our data looks like we can create a data structure that python can make into a table for us.

# %%
import pandas as pd
pd.set_option('display.max_columns', 999) #this makes sure we can see all our columns
information={}
if len(root)==3:
    for node in root[2].iter():
        if type(node.text)!= type(None):
            if "http://" not in node.text:
                information[node.tag]=node.text
    information["full_address"]="{0:} {1:} {2:} {3:}".format(information["street"],information["city"],information["state"],information["zipcode"])
    zillow_data=pd.DataFrame(information,index=[0])
zillow_data
# Out:
#        zpid     street zipcode    city state  latitude    longitude  \
# 0  25759925  51 Exeter   92612  Irvine    CA  33.65125  -117.827541
#
#   FIPScounty      useCode taxAssessmentYear taxAssessment yearBuilt  \
# 0       6059  Condominium              2018      565656.0      1981
#
#   finishedSqFt bathrooms bedrooms lastSoldDate lastSoldPrice  amount  \
# 0         1242       3.0        2   09/17/2007        490000  620429
#
#   last-updated valueChange     low    high percentile zindexValue  \
# 0   10/26/2019       -1638  589408  651450          0     532,300
#
#                 full_address
# 0  51 Exeter Irvine CA 92612

# %% [markdown]
# Now that we know how to get information from the Zillow API we are going to use our LA County Database to push some requests.

# %%
pd.set_option('display.max_columns', 999)
LA_County=pd.read_csv(r"C:\Users\sespejog\OneDrive\Data Sets\LA COUNTY DATA\real_estate.csv")
LA_County.head(5)
# Out:
#    Unnamed: 0     ZIPcode TaxRateArea_CITY         AIN  RollYear  TaxRateArea  \
# 0           0  90031-1636      LOS ANGELES  5304006004      2019            4
# 1           1  90031-1635      LOS ANGELES  5304008001      2019            4
# 2           2  90031-1636      LOS ANGELES  5304006005      2019            4
# 3           3  90031-2070      LOS ANGELES  5205021027      2019            4
# 4           4  90031-1636      LOS ANGELES  5304006006      2019            4
#
#      AssessorID                          PropertyLocation PropertyType  \
# 0  5304-006-004  1004 MONTECITO DR  LOS ANGELES CA  90031          SFR
# 1  5304-008-001  1007 MONTECITO DR  LOS ANGELES CA  90031          SFR
# 2  5304-006-005  1008 MONTECITO DR  LOS ANGELES CA  90031          SFR
# 3  5205-021-027    100 E AVENUE 28  LOS ANGELES CA  90031          C/I
# 4  5304-006-006  1014 MONTECITO DR  LOS ANGELES CA  90031          SFR
#
#   PropertyUseCode GeneralUseType  \
# 0            0100    Residential
# 1            0100    Residential
# 2            0100    Residential
# 3            2670     Commercial
# 4            0100    Residential
#
#                                      SpecificUseType  \
# 0                            Single Family Residence
# 1                            Single Family Residence
# 2                            Single Family Residence
# 3  Auto, Recreation Equipment, Construction Equip...
# 4                            Single Family Residence
#
#                    SpecificUseDetail1 SpecificUseDetail2  \
# 0                                 NaN                NaN
# 1                                 NaN                NaN
# 2                                 NaN                NaN
# 3  Auto Service Centers (No Gasoline)          One Story
# 4                                 NaN                NaN
#
#    totBuildingDataLines  YearBuilt  EffectiveYearBuilt  SQFTmain  Bedrooms  \
# 0                     1       1962                1962      1389         3
# 1                     1       2002                2002      1844         3
# 2                     1       1962                1962      1389         2
# 3                     1       1941                1956      1108         0
# 4                     1       1966                1966      1360         3
#
#    Bathrooms  Units  RecordingDate  LandValue  LandBaseYear  ImprovementValue  \
# 0          2      1       19980626     117363          1998             74766
# 1          3      1       20120523     198640          2002            218505
# 2          2      1       20070629     480414          2007            144119
# 3          0      0       20131121      39531          1975             39805
# 4          2      1       20170802      74956          1986            112451
#
#    ImpBaseYear  TotalLandImpValue  HomeownersExemption  RealEstateExemption  \
# 0         1998             192129                 7000                    0
# 1         2002             417145                 7000                    0
# 2         2007             624533                 7000                    0
# 3         1975              79336                    0                    0
# 4         1986             187407                 7000                    0
#
#    FixtureValue  FixtureExemption  PersonalPropertyValue  \
# 0             0                 0                      0
# 1             0                 0                      0
# 2             0                 0                      0
# 3             0                 0                      0
# 4             0                 0                      0
#
#    PersonalPropertyExemption isTaxableParcel?  TotalValue  TotalExemption  \
# 0                          0                Y      192129            7000
# 1                          0                Y      417145            7000
# 2                          0                Y      624533            7000
# 3                          0                Y       79336               0
# 4                          0                Y      187407            7000
#
#    netTaxableValue SpecialParcelClassification  AdministrativeRegion  Cluster  \
# 0           185129                         NaN                     4     4102
# 1           410145                         NaN                     4     4102
# 2           617533                         NaN                     4     4102
# 3            79336                         NaN                    27    27629
# 4           180407                         NaN                     4     4102
#
#                            ParcelBoundaryDescription  HouseNo HouseFraction  \
# 0                            TRACT NO 1O11O LOT   24     1004           NaN
# 1                            TRACT NO 1O11O LOT   37     1007           NaN
# 2                            TRACT NO 1O11O LOT   25     1008           NaN
# 3  H T HAZARD'S SUB OF LOT 16 GRIFFINS ADD TO E L...      100           NaN
# 4                            TRACT NO 1O11O LOT   26     1014           NaN
#
#   StreetDirection    StreetName UnitNo            City  ZIPcode5  \
# 0             NaN  MONTECITO DR    NaN  LOS ANGELES CA     90031
# 1             NaN  MONTECITO DR    NaN  LOS ANGELES CA     90031
# 2             NaN  MONTECITO DR    NaN  LOS ANGELES CA     90031
# 3               E     AVENUE 28    NaN  LOS ANGELES CA     90031
# 4             NaN  MONTECITO DR    NaN  LOS ANGELES CA     90031
#
#             rowID  CENTER_LAT  CENTER_LON  \
# 0  20195304006004   34.087768 -118.203246
# 1  20195304008001   34.087744 -118.202571
# 2  20195304006005   34.087652 -118.203220
# 3  20195205021027   34.079034 -118.214673
# 4  20195304006006   34.087541 -118.203234
#
#                                           Location 1
# 0  [None, '34.08776772', '-118.20324594', None, F...
# 1  [None, '34.08774435', '-118.20257092', None, F...
# 2  [None, '34.08765199', '-118.20321957', None, F...
# 3  [None, '34.07903447', '-118.21467277', None, F...
# 4  [None, '34.08754092', '-118.20323376', None, F...

# %%
## We are going to filter by residential homes
LA_Residential=LA_County[(LA_County["GeneralUseType"]=="Residential")&(LA_County["EffectiveYearBuilt"]>1990)&(LA_County["SpecificUseType"]=="Single Family Residence")]
LA_Residential.shape
# Out:
# (444, 52)

# %% [markdown]
# ## Using a Dataframe to feed Data to Zillow API
#
# Here is the first result. Once we get it down we will use it for every single house

# %%
string=LA_Residential.iloc[5,:]
new_address=str(string["HouseNo"])+" "+ str(string["StreetName"])
new_city_zip=str(string["City"])+" "+ str(string["ZIPcode5"])

_params={"zws-id":_ZWSID,"address":new_address,"citystatezip":new_city_zip}#we put our inpput parameters into a dictionary 
r= requests.get("http://www.zillow.com/webservice/GetDeepSearchResults.htm",params=_params)#Here is where python makes the request
r.content
# Out:
# b'<?xml version="1.0" encoding="utf-8"?><SearchResults:searchresults xsi:schemaLocation="http://www.zillow.com/static/xsd/SearchResults.xsd http://www.zillowstatic.com/vstatic/80d5e73/static/xsd/SearchResults.xsd" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:SearchResults="http://www.zillow.com/static/xsd/SearchResults.xsd"><request><address>1226 MONTECITO DR</address><citystatezip>LOS ANGELES CA 90031</citystatezip></request><message><text>Request successfully processed</text><code>0</code></message><response><results><result><zpid>20689168</zpid><links><homedetails>http://www.zillow.com/homedetails/1226-Montecito-Dr-Los-Angeles-CA-90031/20689168_zpid/</homedetails><graphsanddata>http://www.zillow.com/homedetails/1226-Montecito-Dr-Los-Angeles-CA-90031/20689168_zpid/#charts-and-data</graphsanddata><mapthishome>http://www.zillow.com/homes/20689168_zpid/</mapthishome><comparables>http://www.zillow.com/homes/comps/20689168_zpid/</comparables></links><address><street>1226 Montecito Dr</street><zipcode>90031</zipcode><city>Los Angeles</city><state>CA</state><latitude>34.087346</latitude><longitude>-118.198436</longitude></address><FIPScounty>6037</FIPScounty><useCode>SingleFamily</useCode><taxAssessmentYear>2019</taxAssessmentYear><taxAssessment>540908.0</taxAssessment><yearBuilt>1993</yearBuilt><lotSizeSqFt>5924</lotSizeSqFt><finishedSqFt>1471</finishedSqFt><bathrooms>3.0</bathrooms><bedrooms>3</bedrooms><lastSoldDate>05/31/2013</lastSoldDate><lastSoldPrice currency="USD">490000</lastSoldPrice><zestimate><amount currency="USD">764688</amount><last-updated>10/26/2019</last-updated><oneWeekChange deprecated="true"></oneWeekChange><valueChange duration="30" currency="USD">-7486</valueChange><valuationRange><low currency="USD">703513</low><high currency="USD">833510</high></valuationRange><percentile>0</percentile></zestimate><localRealEstate><region name="Montecito Heights" id="268316" type="neighborhood"><zindexValue>535,500</zindexValue><links><overview>http://www.zillow.com/local-info/CA-Los-Angeles/Montecito-Heights/r_268316/</overview><forSaleByOwner>http://www.zillow.com/montecito-heights-los-angeles-ca/fsbo/</forSaleByOwner><forSale>http://www.zillow.com/montecito-heights-los-angeles-ca/</forSale></links></region></localRealEstate></result></results></response></SearchResults:searchresults><!-- H:003  T:43ms  S:1181  R:Sun Oct 27 15:02:17 PDT 2019  B:5.0.62786-master.ded4202~delivery_ready.a79bd3d -->'

# %%
def get_info(number,street,city_state,zip_code):
    '''feed data to zillow returns xml string'''
    new_address=str(number)+" "+ str(street)
    new_city_zip=str(city_state)+" "+ str(zip_code)
    _params={"zws-id":_ZWSID,"address":new_address,"citystatezip":new_city_zip}#we put our inpput parameters into a dictionary 
    r= requests.get("http://www.zillow.com/webservice/GetDeepSearchResults.htm",params=_params)#Here is where python makes the request
    return r.content

def parse_xml(xml_string,number,street,city_state,zip_code):
    root=ET.fromstring(xml_string)
    information={}
    outer_dict={}
    if len(root)==3:
        for node in root[2].iter():
            if type(node.text)!= type(None):
                if "http://" not in node.text:
                    information[node.tag]=node.text
        outer_dict["{0:} {1:} {2:} {3:}".format(number,street,city_state,zip_code)]=information
    return outer_dict

xml_test=get_info(string["HouseNo"],string["StreetName"],string["City"],string["ZIPcode5"])
parse_xml(xml_test,string["HouseNo"],string["StreetName"],string["City"],string["ZIPcode5"])
# Out:
# {'1226 MONTECITO DR LOS ANGELES CA 90031': {'zpid': '20689168',
#   'street': '1226 Montecito Dr',
#   'zipcode': '90031',
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'latitude': '34.087346',
#   'longitude': '-118.198436',
#   'FIPScounty': '6037',
#   'useCode': 'SingleFamily',
#   'taxAssessmentYear': '2019',
#   'taxAssessment': '540908.0',
#   'yearBuilt': '1993',
#   'lotSizeSqFt': '5924',
#   'finishedSqFt': '1471',
#   'bathrooms': '3.0',
#   'bedrooms': '3',
#   'lastSoldDate': '05/31/2013',
#   'lastSoldPrice': '490000',
#   'amount': '764688',
#   'last-updated': '10/26/2019',
#   'valueChange': '-7486',
#   'low': '703513',
#   'high': '833510',
#   'percentile': '0',
#   'zindexValue': '535,500'}}

# %% [markdown]
# ## Now we use our functions on our LA Residential Dataframe

# %%
Main_List=[]
for i in LA_Residential.index:
    xml_test=get_info(LA_Residential.loc[i,"HouseNo"],LA_Residential.loc[i,"StreetName"],LA_Residential.loc[i,"City"],LA_Residential.loc[i,"ZIPcode5"])
    Main_List.append(parse_xml(xml_test,LA_Residential.loc[i,"HouseNo"],LA_Residential.loc[i,"StreetName"],LA_Residential.loc[i,"City"],LA_Residential.loc[i,"ZIPcode5"]))

# %%
Main_List[:5]
# Out:
# [{'1007 MONTECITO DR LOS ANGELES CA 90031': {'zpid': '20689097',
#    'street': '1007 Montecito Dr',
#    'zipcode': '90031',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'latitude': '34.087739',
#    'longitude': '-118.202558',
#    'FIPScounty': '6037',
#    'useCode': 'SingleFamily',
#    'taxAssessmentYear': '2019',
#    'taxAssessment': '417145.0',
#    'yearBuilt': '2002',
#    'lotSizeSqFt': '5016',
#    'finishedSqFt': '1844',
#    'bathrooms': '3.0',
#    'bedrooms': '3',
#    'lastSoldDate': '11/06/2001',
#    'lastSoldPrice': '315000',
#    'amount': '822316',
#    'last-updated': '10/26/2019',
#    'valueChange': '25890',
#    'low': '772977',
#    'high': '871655',
#    'percentile': '0',
#    'zindexValue': '535,500'}},
#  {'1020 MONTECITO DR LOS ANGELES CA 90031': {'zpid': '20689074',
#    'street': '1020 Montecito Dr',
#    'zipcode': '90031',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'latitude': '34.087427',
#    'longitude': '-118.203251',
#    'FIPScounty': '6037',
#    'useCode': 'SingleFamily',
#    'taxAssessmentYear': '2019',
#    'taxAssessment': '219621.0',
#    'yearBuilt': '1991',
#    'lotSizeSqFt': '7648',
#    'finishedSqFt': '1822',
#    'bathrooms': '2.0',
#    'bedrooms': '3',
#    'amount': '801818',
#    'last-updated': '10/26/2019',
#    'valueChange': '21416',
#    'low': '737673',
#    'high': '857945',
#    'percentile': '0',
#    'zindexValue': '535,500'}},
#  {'1072 MONTECITO DR LOS ANGELES CA 90031': {'zpid': '20689138',
#    'street': '1072 Montecito Dr',
#    'zipcode': '90031',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'latitude': '34.086643',
#    'longitude': '-118.201981',
#    'FIPScounty': '6037',
#    'useCode': 'SingleFamily',
#    'taxAssessmentYear': '2019',
#    'taxAssessment': '325598.0',
#    'yearBuilt': '2017',
#    'lotSizeSqFt': '5200',
#    'finishedSqFt': '2068',
#    'bathrooms': '3.0',
#    'bedrooms': '3',
#    'lastSoldDate': '11/12/2014',
#    'lastSoldPrice': '90000',
#    'amount': '804888',
#    'last-updated': '10/26/2019',
#    'valueChange': '16206',
#    'low': '740497',
#    'high': '869279',
#    'percentile': '0',
#    'zindexValue': '535,500'}},
#  {'1092 MONTECITO DR LOS ANGELES CA 90031': {'zpid': '20689133',
#    'street': '1092 Montecito Dr',
#    'zipcode': '90031',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'latitude': '34.087098',
#    'longitude': '-118.201609',
#    'FIPScounty': '6037',
#    'useCode': 'Condominium',
#    'taxAssessmentYear': '2019',
#    'taxAssessment': '920754.0',
#    'yearBuilt': '1965',
#    'lotSizeSqFt': '5200',
#    'finishedSqFt': '1581',
#    'bathrooms': '3.0',
#    'bedrooms': '4',
#    'lastSoldDate': '05/05/2017',
#    'lastSoldPrice': '885000',
#    'amount': '991635',
#    'last-updated': '10/26/2019',
#    'valueChange': '2286',
#    'low': '892472',
#    'high': '1110631',
#    'percentile': '0',
#    'zindexValue': '535,500'}},
#  {'1196 MONTECITO DR LOS ANGELES CA 90031': {'zpid': '82872725',
#    'street': '1196 Montecito Dr',
#    'zipcode': '90031',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'latitude': '34.087526',
#    'longitude': '-118.199365',
#    'FIPScounty': '6037',
#    'useCode': 'SingleFamily',
#    'taxAssessmentYear': '2019',
#    'taxAssessment': '420326.0',
#    'yearBuilt': '2006',
#    'lotSizeSqFt': '3070',
#    'finishedSqFt': '1850',
#    'bathrooms': '2.0',
#    'bedrooms': '2',
#    'amount': '993155',
#    'last-updated': '10/26/2019',
#    'valueChange': '68',
#    'low': '943497',
#    'high': '1042813',
#    'percentile': '0',
#    'zindexValue': '535,500'}}]

# %%
Zillow_Database=[]
for i in Main_List:
    temp_dataframe=pd.DataFrame.from_dict(i.values())
    temp_dataframe["Full_Address"]=i.keys()
    temp_dataframe=temp_dataframe.set_index(temp_dataframe["Full_Address"])
    Zillow_Database.append(temp_dataframe)
result = pd.concat(Zillow_Database,sort=True)
result
   # for attributes in i.values():
    #    print(attributes.values())
# Out:
#                                          FIPScounty  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031         6037
# 1020 MONTECITO DR LOS ANGELES CA 90031         6037
# 1072 MONTECITO DR LOS ANGELES CA 90031         6037
# 1092 MONTECITO DR LOS ANGELES CA 90031         6037
# 1196 MONTECITO DR LOS ANGELES CA 90031         6037
# 1226 MONTECITO DR LOS ANGELES CA 90031         6037
# 122 AVENUE 23 LOS ANGELES CA 90031              NaN
# 122 AVENUE 23 LOS ANGELES CA 90031              NaN
# 122 AVENUE 23 LOS ANGELES CA 90031              NaN
# 122 AVENUE 23 LOS ANGELES CA 90031              NaN
# 122 AVENUE 23 LOS ANGELES CA 90031              NaN
# 122 AVENUE 23 LOS ANGELES CA 90031              NaN
# 1331 MONTECITO CIR LOS ANGELES CA 90031        6037
# 1414 MONTECITO DR LOS ANGELES CA 90031         6037
# 1418 MONTECITO DR LOS ANGELES CA 90031         6037
# 1430 MONTECITO DR LOS ANGELES CA 90031         6037
# 148 AVENUE 25 LOS ANGELES CA 90031             6037
# 1509 LANDA ST LOS ANGELES CA 90031             6037
# 157 AVENUE 25 LOS ANGELES CA 90031             6037
# 1936 THOMAS ST LOS ANGELES CA 90031            6037
# 2125 VALLEJO ST LOS ANGELES CA 90031           6037
# 2212 GATES ST LOS ANGELES CA 90031             6037
# 2219 GLOVER PL LOS ANGELES CA 90031            6037
# 2222 SICHEL ST LOS ANGELES CA 90031            6037
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031       6037
# 2230 OROS ST LOS ANGELES CA 90031              6037
# 2237 SHOREDALE AVE LOS ANGELES CA 90031        6037
# 223 AVENUE 38 LOS ANGELES CA 90031             6037
# 2244 SHOREDALE AVE LOS ANGELES CA 90031        6037
# 2253 ELMGROVE ST LOS ANGELES CA 90031          6037
# ...                                             ...
# 4128 MERCURY AVE LOS ANGELES CA 90031          6037
# 4130 MERCURY AVE LOS ANGELES CA 90031          6037
# 4134 MERCURY AVE LOS ANGELES CA 90031          6037
# 489 CLIFTON ST LOS ANGELES CA 90031            6037
# 548 MONTECITO DR LOS ANGELES CA 90031          6037
# 600 MONTECITO DR LOS ANGELES CA 90031          6037
# 610 MONTECITO DR LOS ANGELES CA 90031          6037
# 629 AVENUE 28 LOS ANGELES CA 90031             6037
# 717 MONTECITO DR LOS ANGELES CA 90031          6037
# 734 AVENUE 43 LOS ANGELES CA 90031             6037
# 749 AVENUE 43 LOS ANGELES CA 90031             6037
# 749 MONTECITO DR LOS ANGELES CA 90031          6037
# 755 MONTECITO DR LOS ANGELES CA 90031          6037
# 757 AVENUE 43 LOS ANGELES CA 90031             6037
# 759 MONTECITO DR LOS ANGELES CA 90031          6037
# 763 MONTECITO DR LOS ANGELES CA 90031          6037
# 767 MONTECITO DR LOS ANGELES CA 90031          6037
# 771 MONTECITO DR LOS ANGELES CA 90031          6037
# 775 MONTECITO DR LOS ANGELES CA 90031          6037
# 781 MONTECITO DR LOS ANGELES CA 90031          6037
# 782 MONTECITO DR LOS ANGELES CA 90031          6037
# 834 MONTECITO DR LOS ANGELES CA 90031          6037
# 846 MONTECITO DR LOS ANGELES CA 90031          6037
# 888 MONTECITO DR LOS ANGELES CA 90031          6037
# 905 MONTECITO DR LOS ANGELES CA 90031          6037
# 906 MONTECITO DR LOS ANGELES CA 90031          6037
# 909 MONTECITO DR LOS ANGELES CA 90031          6037
# 913 MONTECITO DR LOS ANGELES CA 90031          6037
# 937 MONTECITO DR LOS ANGELES CA 90031          6037
# 969 MONTECITO DR LOS ANGELES CA 90031          6037
#
#                                                                       Full_Address  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031      1007 MONTECITO DR LOS ANGELES CA 90031
# 1020 MONTECITO DR LOS ANGELES CA 90031      1020 MONTECITO DR LOS ANGELES CA 90031
# 1072 MONTECITO DR LOS ANGELES CA 90031      1072 MONTECITO DR LOS ANGELES CA 90031
# 1092 MONTECITO DR LOS ANGELES CA 90031      1092 MONTECITO DR LOS ANGELES CA 90031
# 1196 MONTECITO DR LOS ANGELES CA 90031      1196 MONTECITO DR LOS ANGELES CA 90031
# 1226 MONTECITO DR LOS ANGELES CA 90031      1226 MONTECITO DR LOS ANGELES CA 90031
# 122 AVENUE 23 LOS ANGELES CA 90031              122 AVENUE 23 LOS ANGELES CA 90031
# 122 AVENUE 23 LOS ANGELES CA 90031              122 AVENUE 23 LOS ANGELES CA 90031
# 122 AVENUE 23 LOS ANGELES CA 90031              122 AVENUE 23 LOS ANGELES CA 90031
# 122 AVENUE 23 LOS ANGELES CA 90031              122 AVENUE 23 LOS ANGELES CA 90031
# 122 AVENUE 23 LOS ANGELES CA 90031              122 AVENUE 23 LOS ANGELES CA 90031
# 122 AVENUE 23 LOS ANGELES CA 90031              122 AVENUE 23 LOS ANGELES CA 90031
# 1331 MONTECITO CIR LOS ANGELES CA 90031    1331 MONTECITO CIR LOS ANGELES CA 90031
# 1414 MONTECITO DR LOS ANGELES CA 90031      1414 MONTECITO DR LOS ANGELES CA 90031
# 1418 MONTECITO DR LOS ANGELES CA 90031      1418 MONTECITO DR LOS ANGELES CA 90031
# 1430 MONTECITO DR LOS ANGELES CA 90031      1430 MONTECITO DR LOS ANGELES CA 90031
# 148 AVENUE 25 LOS ANGELES CA 90031              148 AVENUE 25 LOS ANGELES CA 90031
# 1509 LANDA ST LOS ANGELES CA 90031              1509 LANDA ST LOS ANGELES CA 90031
# 157 AVENUE 25 LOS ANGELES CA 90031              157 AVENUE 25 LOS ANGELES CA 90031
# 1936 THOMAS ST LOS ANGELES CA 90031            1936 THOMAS ST LOS ANGELES CA 90031
# 2125 VALLEJO ST LOS ANGELES CA 90031          2125 VALLEJO ST LOS ANGELES CA 90031
# 2212 GATES ST LOS ANGELES CA 90031              2212 GATES ST LOS ANGELES CA 90031
# 2219 GLOVER PL LOS ANGELES CA 90031            2219 GLOVER PL LOS ANGELES CA 90031
# 2222 SICHEL ST LOS ANGELES CA 90031            2222 SICHEL ST LOS ANGELES CA 90031
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031  2224 MEADOWVALE AVE LOS ANGELES CA 90031
# 2230 OROS ST LOS ANGELES CA 90031                2230 OROS ST LOS ANGELES CA 90031
# 2237 SHOREDALE AVE LOS ANGELES CA 90031    2237 SHOREDALE AVE LOS ANGELES CA 90031
# 223 AVENUE 38 LOS ANGELES CA 90031              223 AVENUE 38 LOS ANGELES CA 90031
# 2244 SHOREDALE AVE LOS ANGELES CA 90031    2244 SHOREDALE AVE LOS ANGELES CA 90031
# 2253 ELMGROVE ST LOS ANGELES CA 90031        2253 ELMGROVE ST LOS ANGELES CA 90031
# ...                                                                            ...
# 4128 MERCURY AVE LOS ANGELES CA 90031        4128 MERCURY AVE LOS ANGELES CA 90031
# 4130 MERCURY AVE LOS ANGELES CA 90031        4130 MERCURY AVE LOS ANGELES CA 90031
# 4134 MERCURY AVE LOS ANGELES CA 90031        4134 MERCURY AVE LOS ANGELES CA 90031
# 489 CLIFTON ST LOS ANGELES CA 90031            489 CLIFTON ST LOS ANGELES CA 90031
# 548 MONTECITO DR LOS ANGELES CA 90031        548 MONTECITO DR LOS ANGELES CA 90031
# 600 MONTECITO DR LOS ANGELES CA 90031        600 MONTECITO DR LOS ANGELES CA 90031
# 610 MONTECITO DR LOS ANGELES CA 90031        610 MONTECITO DR LOS ANGELES CA 90031
# 629 AVENUE 28 LOS ANGELES CA 90031              629 AVENUE 28 LOS ANGELES CA 90031
# 717 MONTECITO DR LOS ANGELES CA 90031        717 MONTECITO DR LOS ANGELES CA 90031
# 734 AVENUE 43 LOS ANGELES CA 90031              734 AVENUE 43 LOS ANGELES CA 90031
# 749 AVENUE 43 LOS ANGELES CA 90031              749 AVENUE 43 LOS ANGELES CA 90031
# 749 MONTECITO DR LOS ANGELES CA 90031        749 MONTECITO DR LOS ANGELES CA 90031
# 755 MONTECITO DR LOS ANGELES CA 90031        755 MONTECITO DR LOS ANGELES CA 90031
# 757 AVENUE 43 LOS ANGELES CA 90031              757 AVENUE 43 LOS ANGELES CA 90031
# 759 MONTECITO DR LOS ANGELES CA 90031        759 MONTECITO DR LOS ANGELES CA 90031
# 763 MONTECITO DR LOS ANGELES CA 90031        763 MONTECITO DR LOS ANGELES CA 90031
# 767 MONTECITO DR LOS ANGELES CA 90031        767 MONTECITO DR LOS ANGELES CA 90031
# 771 MONTECITO DR LOS ANGELES CA 90031        771 MONTECITO DR LOS ANGELES CA 90031
# 775 MONTECITO DR LOS ANGELES CA 90031        775 MONTECITO DR LOS ANGELES CA 90031
# 781 MONTECITO DR LOS ANGELES CA 90031        781 MONTECITO DR LOS ANGELES CA 90031
# 782 MONTECITO DR LOS ANGELES CA 90031        782 MONTECITO DR LOS ANGELES CA 90031
# 834 MONTECITO DR LOS ANGELES CA 90031        834 MONTECITO DR LOS ANGELES CA 90031
# 846 MONTECITO DR LOS ANGELES CA 90031        846 MONTECITO DR LOS ANGELES CA 90031
# 888 MONTECITO DR LOS ANGELES CA 90031        888 MONTECITO DR LOS ANGELES CA 90031
# 905 MONTECITO DR LOS ANGELES CA 90031        905 MONTECITO DR LOS ANGELES CA 90031
# 906 MONTECITO DR LOS ANGELES CA 90031        906 MONTECITO DR LOS ANGELES CA 90031
# 909 MONTECITO DR LOS ANGELES CA 90031        909 MONTECITO DR LOS ANGELES CA 90031
# 913 MONTECITO DR LOS ANGELES CA 90031        913 MONTECITO DR LOS ANGELES CA 90031
# 937 MONTECITO DR LOS ANGELES CA 90031        937 MONTECITO DR LOS ANGELES CA 90031
# 969 MONTECITO DR LOS ANGELES CA 90031        969 MONTECITO DR LOS ANGELES CA 90031
#
#                                            amount bathrooms bedrooms  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031     822316       3.0        3
# 1020 MONTECITO DR LOS ANGELES CA 90031     801818       2.0        3
# 1072 MONTECITO DR LOS ANGELES CA 90031     804888       3.0        3
# 1092 MONTECITO DR LOS ANGELES CA 90031     991635       3.0        4
# 1196 MONTECITO DR LOS ANGELES CA 90031     993155       2.0        2
# 1226 MONTECITO DR LOS ANGELES CA 90031     764688       3.0        3
# 122 AVENUE 23 LOS ANGELES CA 90031         738157       2.5        3
# 122 AVENUE 23 LOS ANGELES CA 90031         738157       2.5        3
# 122 AVENUE 23 LOS ANGELES CA 90031         738157       2.5        3
# 122 AVENUE 23 LOS ANGELES CA 90031         738157       2.5        3
# 122 AVENUE 23 LOS ANGELES CA 90031         738157       2.5        3
# 122 AVENUE 23 LOS ANGELES CA 90031         738157       2.5        3
# 1331 MONTECITO CIR LOS ANGELES CA 90031    728002       2.0        2
# 1414 MONTECITO DR LOS ANGELES CA 90031    1005586       3.0        3
# 1418 MONTECITO DR LOS ANGELES CA 90031     827388       3.0        3
# 1430 MONTECITO DR LOS ANGELES CA 90031     788957       3.0        3
# 148 AVENUE 25 LOS ANGELES CA 90031         851798       3.0        4
# 1509 LANDA ST LOS ANGELES CA 90031         698144       1.0        1
# 157 AVENUE 25 LOS ANGELES CA 90031         798467       2.0        3
# 1936 THOMAS ST LOS ANGELES CA 90031       1071213       4.0        3
# 2125 VALLEJO ST LOS ANGELES CA 90031       867783       3.0        4
# 2212 GATES ST LOS ANGELES CA 90031         756829       3.0        5
# 2219 GLOVER PL LOS ANGELES CA 90031        809017       3.0        4
# 2222 SICHEL ST LOS ANGELES CA 90031       1327398       4.0        6
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031  1252299       3.0        4
# 2230 OROS ST LOS ANGELES CA 90031          718949       2.0        1
# 2237 SHOREDALE AVE LOS ANGELES CA 90031    996711       2.0        3
# 223 AVENUE 38 LOS ANGELES CA 90031         756432       2.0        2
# 2244 SHOREDALE AVE LOS ANGELES CA 90031   1004101       2.0        4
# 2253 ELMGROVE ST LOS ANGELES CA 90031      955185       2.0        3
# ...                                           ...       ...      ...
# 4128 MERCURY AVE LOS ANGELES CA 90031      733868       3.0        3
# 4130 MERCURY AVE LOS ANGELES CA 90031      733924       3.0        3
# 4134 MERCURY AVE LOS ANGELES CA 90031      739337       2.5        3
# 489 CLIFTON ST LOS ANGELES CA 90031        877374       3.5        4
# 548 MONTECITO DR LOS ANGELES CA 90031     1084096       3.0        3
# 600 MONTECITO DR LOS ANGELES CA 90031      886161       3.0        3
# 610 MONTECITO DR LOS ANGELES CA 90031     1297666       4.5        5
# 629 AVENUE 28 LOS ANGELES CA 90031            NaN       NaN        0
# 717 MONTECITO DR LOS ANGELES CA 90031     1256424       4.0        4
# 734 AVENUE 43 LOS ANGELES CA 90031         540521       2.0        3
# 749 AVENUE 43 LOS ANGELES CA 90031         825744       2.0        3
# 749 MONTECITO DR LOS ANGELES CA 90031      807377       2.5        3
# 755 MONTECITO DR LOS ANGELES CA 90031      765920       3.0        3
# 757 AVENUE 43 LOS ANGELES CA 90031         864325       3.0        4
# 759 MONTECITO DR LOS ANGELES CA 90031      793977       3.0        3
# 763 MONTECITO DR LOS ANGELES CA 90031      765838       2.5        3
# 767 MONTECITO DR LOS ANGELES CA 90031      786664       3.0        3
# 771 MONTECITO DR LOS ANGELES CA 90031      819830       3.0        3
# 775 MONTECITO DR LOS ANGELES CA 90031      645905       2.5        3
# 781 MONTECITO DR LOS ANGELES CA 90031      831282       3.0        3
# 782 MONTECITO DR LOS ANGELES CA 90031      898318       3.0        3
# 834 MONTECITO DR LOS ANGELES CA 90031     1007519       4.0        3
# 846 MONTECITO DR LOS ANGELES CA 90031      826548       3.0        3
# 888 MONTECITO DR LOS ANGELES CA 90031      894815       3.0        4
# 905 MONTECITO DR LOS ANGELES CA 90031      794791       3.0        3
# 906 MONTECITO DR LOS ANGELES CA 90031      898108       3.0        4
# 909 MONTECITO DR LOS ANGELES CA 90031      725076       3.0        3
# 913 MONTECITO DR LOS ANGELES CA 90031      849540       3.0        3
# 937 MONTECITO DR LOS ANGELES CA 90031      713078       2.0        2
# 969 MONTECITO DR LOS ANGELES CA 90031      876596       3.0        2
#
#                                                  city finishedSqFt     high  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031    Los Angeles         1844   871655
# 1020 MONTECITO DR LOS ANGELES CA 90031    Los Angeles         1822   857945
# 1072 MONTECITO DR LOS ANGELES CA 90031    Los Angeles         2068   869279
# 1092 MONTECITO DR LOS ANGELES CA 90031    Los Angeles         1581  1110631
# 1196 MONTECITO DR LOS ANGELES CA 90031    Los Angeles         1850  1042813
# 1226 MONTECITO DR LOS ANGELES CA 90031    Los Angeles         1471   833510
# 122 AVENUE 23 LOS ANGELES CA 90031        Los Angeles         1650   797210
# 122 AVENUE 23 LOS ANGELES CA 90031        Los Angeles         1650   797210
# 122 AVENUE 23 LOS ANGELES CA 90031        Los Angeles         1650   797210
# 122 AVENUE 23 LOS ANGELES CA 90031        Los Angeles         1650   797210
# 122 AVENUE 23 LOS ANGELES CA 90031        Los Angeles         1650   797210
# 122 AVENUE 23 LOS ANGELES CA 90031        Los Angeles         1650   797210
# 1331 MONTECITO CIR LOS ANGELES CA 90031   Los Angeles         1292   778962
# 1414 MONTECITO DR LOS ANGELES CA 90031    Los Angeles         1767  1065921
# 1418 MONTECITO DR LOS ANGELES CA 90031    Los Angeles         1869   885305
# 1430 MONTECITO DR LOS ANGELES CA 90031    Los angeles         1814   852074
# 148 AVENUE 25 LOS ANGELES CA 90031        Los Angeles         2210   911424
# 1509 LANDA ST LOS ANGELES CA 90031        Los Angeles          447   767958
# 157 AVENUE 25 LOS ANGELES CA 90031        Los Angeles         1651   870329
# 1936 THOMAS ST LOS ANGELES CA 90031       Los angeles         3360  1199759
# 2125 VALLEJO ST LOS ANGELES CA 90031      Los Angeles         2475  1032662
# 2212 GATES ST LOS ANGELES CA 90031        Los Angeles         2016   809807
# 2219 GLOVER PL LOS ANGELES CA 90031       Los Angeles         1680   889919
# 2222 SICHEL ST LOS ANGELES CA 90031       Los Angeles         4572  1553056
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031  Los Angeles         2110  1377529
# 2230 OROS ST LOS ANGELES CA 90031         Los Angeles          804   769275
# 2237 SHOREDALE AVE LOS ANGELES CA 90031   Los Angeles         2016  1156185
# 223 AVENUE 38 LOS ANGELES CA 90031        Los Angeles         1115   862332
# 2244 SHOREDALE AVE LOS ANGELES CA 90031   Los Angeles         1461  1164757
# 2253 ELMGROVE ST LOS ANGELES CA 90031     Los Angeles         1500  1060255
# ...                                               ...          ...      ...
# 4128 MERCURY AVE LOS ANGELES CA 90031     Los Angeles         1402   777900
# 4130 MERCURY AVE LOS ANGELES CA 90031     Los Angeles         1402   777959
# 4134 MERCURY AVE LOS ANGELES CA 90031     Los Angeles         1402   783697
# 489 CLIFTON ST LOS ANGELES CA 90031       Los Angeles         2109   938790
# 548 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         3379  1235869
# 600 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         2300   965915
# 610 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         3457  1479339
# 629 AVENUE 28 LOS ANGELES CA 90031        Los Angeles         1986      NaN
# 717 MONTECITO DR LOS ANGELES CA 90031     Los angeles         2994  1419759
# 734 AVENUE 43 LOS ANGELES CA 90031        Los Angeles         1271   578357
# 749 AVENUE 43 LOS ANGELES CA 90031        Los Angeles         1913   883546
# 749 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1818   871967
# 755 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1408   857830
# 757 AVENUE 43 LOS ANGELES CA 90031        Los Angeles         2279   907541
# 759 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1408   889254
# 763 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1408   850080
# 767 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1818   873197
# 771 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1818   910011
# 775 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1579   716955
# 781 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1579   931036
# 782 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1866   997133
# 834 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1795  1108271
# 846 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         1736   876141
# 888 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         2305   957452
# 905 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         2236   882218
# 906 MONTECITO DR LOS ANGELES CA 90031     Los angeles         2320   987919
# 909 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         2236   761330
# 913 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         2236   909008
# 937 MONTECITO DR LOS ANGELES CA 90031     Los Angeles          960   770124
# 969 MONTECITO DR LOS ANGELES CA 90031     Los Angeles         2212   937958
#
#                                          last-updated lastSoldDate  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031     10/26/2019   11/06/2001
# 1020 MONTECITO DR LOS ANGELES CA 90031     10/26/2019          NaN
# 1072 MONTECITO DR LOS ANGELES CA 90031     10/26/2019   11/12/2014
# 1092 MONTECITO DR LOS ANGELES CA 90031     10/26/2019   05/05/2017
# 1196 MONTECITO DR LOS ANGELES CA 90031     10/26/2019          NaN
# 1226 MONTECITO DR LOS ANGELES CA 90031     10/26/2019   05/31/2013
# 122 AVENUE 23 LOS ANGELES CA 90031         10/26/2019          NaN
# 122 AVENUE 23 LOS ANGELES CA 90031         10/26/2019          NaN
# 122 AVENUE 23 LOS ANGELES CA 90031         10/26/2019          NaN
# 122 AVENUE 23 LOS ANGELES CA 90031         10/26/2019          NaN
# 122 AVENUE 23 LOS ANGELES CA 90031         10/26/2019          NaN
# 122 AVENUE 23 LOS ANGELES CA 90031         10/26/2019          NaN
# 1331 MONTECITO CIR LOS ANGELES CA 90031    10/26/2019          NaN
# 1414 MONTECITO DR LOS ANGELES CA 90031     10/26/2019   12/23/1999
# 1418 MONTECITO DR LOS ANGELES CA 90031     10/26/2019   12/17/1999
# 1430 MONTECITO DR LOS ANGELES CA 90031     10/26/2019   05/19/2014
# 148 AVENUE 25 LOS ANGELES CA 90031         10/26/2019          NaN
# 1509 LANDA ST LOS ANGELES CA 90031         10/26/2019   06/06/2006
# 157 AVENUE 25 LOS ANGELES CA 90031         10/26/2019          NaN
# 1936 THOMAS ST LOS ANGELES CA 90031        01/01/1970          NaN
# 2125 VALLEJO ST LOS ANGELES CA 90031       10/26/2019   06/28/2014
# 2212 GATES ST LOS ANGELES CA 90031         10/26/2019   07/24/2003
# 2219 GLOVER PL LOS ANGELES CA 90031        10/26/2019   06/04/2019
# 2222 SICHEL ST LOS ANGELES CA 90031        10/26/2019   08/05/2004
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031   10/26/2019   09/20/2019
# 2230 OROS ST LOS ANGELES CA 90031          10/26/2019   09/27/2007
# 2237 SHOREDALE AVE LOS ANGELES CA 90031    10/26/2019          NaN
# 223 AVENUE 38 LOS ANGELES CA 90031         10/26/2019   08/14/2015
# 2244 SHOREDALE AVE LOS ANGELES CA 90031    10/26/2019   10/28/2011
# 2253 ELMGROVE ST LOS ANGELES CA 90031      10/26/2019   06/29/2018
# ...                                               ...          ...
# 4128 MERCURY AVE LOS ANGELES CA 90031      10/26/2019   04/05/2001
# 4130 MERCURY AVE LOS ANGELES CA 90031      10/26/2019   10/06/1999
# 4134 MERCURY AVE LOS ANGELES CA 90031      10/26/2019   10/31/2000
# 489 CLIFTON ST LOS ANGELES CA 90031        10/26/2019   07/29/2010
# 548 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   11/04/1993
# 600 MONTECITO DR LOS ANGELES CA 90031      10/26/2019          NaN
# 610 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   09/22/2014
# 629 AVENUE 28 LOS ANGELES CA 90031         01/01/1970   06/16/2016
# 717 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   09/08/2015
# 734 AVENUE 43 LOS ANGELES CA 90031         10/26/2019   01/13/2015
# 749 AVENUE 43 LOS ANGELES CA 90031         10/26/2019   12/30/2008
# 749 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   04/10/2015
# 755 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   11/09/2016
# 757 AVENUE 43 LOS ANGELES CA 90031         10/26/2019   03/23/2000
# 759 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   11/17/2016
# 763 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   11/28/2017
# 767 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   08/16/2017
# 771 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   09/08/2016
# 775 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   05/07/2018
# 781 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   12/12/2016
# 782 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   09/18/2017
# 834 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   03/22/2019
# 846 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   09/01/2015
# 888 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   05/24/2011
# 905 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   10/05/2016
# 906 MONTECITO DR LOS ANGELES CA 90031      01/01/1970   03/15/2018
# 909 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   10/21/2016
# 913 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   02/28/2013
# 937 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   05/01/1998
# 969 MONTECITO DR LOS ANGELES CA 90031      10/26/2019   11/24/1992
#
#                                          lastSoldPrice   latitude  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031          315000  34.087739
# 1020 MONTECITO DR LOS ANGELES CA 90031             NaN  34.087427
# 1072 MONTECITO DR LOS ANGELES CA 90031           90000  34.086643
# 1092 MONTECITO DR LOS ANGELES CA 90031          885000  34.087098
# 1196 MONTECITO DR LOS ANGELES CA 90031             NaN  34.087526
# 1226 MONTECITO DR LOS ANGELES CA 90031          490000  34.087346
# 122 AVENUE 23 LOS ANGELES CA 90031                 NaN  34.076503
# 122 AVENUE 23 LOS ANGELES CA 90031                 NaN  34.076503
# 122 AVENUE 23 LOS ANGELES CA 90031                 NaN  34.076503
# 122 AVENUE 23 LOS ANGELES CA 90031                 NaN  34.076503
# 122 AVENUE 23 LOS ANGELES CA 90031                 NaN  34.076503
# 122 AVENUE 23 LOS ANGELES CA 90031                 NaN  34.076503
# 1331 MONTECITO CIR LOS ANGELES CA 90031            NaN  34.088763
# 1414 MONTECITO DR LOS ANGELES CA 90031          265000  34.089263
# 1418 MONTECITO DR LOS ANGELES CA 90031          273000  34.089385
# 1430 MONTECITO DR LOS ANGELES CA 90031          695000  34.089878
# 148 AVENUE 25 LOS ANGELES CA 90031                 NaN  34.077524
# 1509 LANDA ST LOS ANGELES CA 90031              125000  34.094775
# 157 AVENUE 25 LOS ANGELES CA 90031                 NaN  34.077509
# 1936 THOMAS ST LOS ANGELES CA 90031                NaN    34.0679
# 2125 VALLEJO ST LOS ANGELES CA 90031            550000  34.071049
# 2212 GATES ST LOS ANGELES CA 90031              185000  34.070674
# 2219 GLOVER PL LOS ANGELES CA 90031             800000  34.090073
# 2222 SICHEL ST LOS ANGELES CA 90031             140000   34.07088
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031       1250000  34.088714
# 2230 OROS ST LOS ANGELES CA 90031               240000  34.086374
# 2237 SHOREDALE AVE LOS ANGELES CA 90031            NaN  34.088708
# 223 AVENUE 38 LOS ANGELES CA 90031              610000  34.089472
# 2244 SHOREDALE AVE LOS ANGELES CA 90031         305000  34.088534
# 2253 ELMGROVE ST LOS ANGELES CA 90031           930000   34.08686
# ...                                                ...        ...
# 4128 MERCURY AVE LOS ANGELES CA 90031           140000  34.084581
# 4130 MERCURY AVE LOS ANGELES CA 90031           145000  34.084585
# 4134 MERCURY AVE LOS ANGELES CA 90031           140000  34.084588
# 489 CLIFTON ST LOS ANGELES CA 90031             419000  34.080223
# 548 MONTECITO DR LOS ANGELES CA 90031           256000  34.091738
# 600 MONTECITO DR LOS ANGELES CA 90031              NaN  34.091916
# 610 MONTECITO DR LOS ANGELES CA 90031           798800  34.092036
# 629 AVENUE 28 LOS ANGELES CA 90031              600000  34.083516
# 717 MONTECITO DR LOS ANGELES CA 90031           850000  34.089762
# 734 AVENUE 43 LOS ANGELES CA 90031              625000  34.089933
# 749 AVENUE 43 LOS ANGELES CA 90031              105000  34.090004
# 749 MONTECITO DR LOS ANGELES CA 90031           722500  34.090858
# 755 MONTECITO DR LOS ANGELES CA 90031           660000  34.090727
# 757 AVENUE 43 LOS ANGELES CA 90031              257500  34.089892
# 759 MONTECITO DR LOS ANGELES CA 90031           685000  34.090684
# 763 MONTECITO DR LOS ANGELES CA 90031           719000  34.090651
# 767 MONTECITO DR LOS ANGELES CA 90031           720000   34.09071
# 771 MONTECITO DR LOS ANGELES CA 90031           680000  34.090789
# 775 MONTECITO DR LOS ANGELES CA 90031           625000  34.090853
# 781 MONTECITO DR LOS ANGELES CA 90031           720000   34.09093
# 782 MONTECITO DR LOS ANGELES CA 90031           829000  34.091218
# 834 MONTECITO DR LOS ANGELES CA 90031           989000  34.089539
# 846 MONTECITO DR LOS ANGELES CA 90031           647000  34.089356
# 888 MONTECITO DR LOS ANGELES CA 90031           522000  34.088889
# 905 MONTECITO DR LOS ANGELES CA 90031           665000  34.088582
# 906 MONTECITO DR LOS ANGELES CA 90031           140000  34.089049
# 909 MONTECITO DR LOS ANGELES CA 90031           645000  34.088618
# 913 MONTECITO DR LOS ANGELES CA 90031           516000  34.088654
# 937 MONTECITO DR LOS ANGELES CA 90031           125000  34.088772
# 969 MONTECITO DR LOS ANGELES CA 90031           208000  34.088664
#
#                                             longitude lotSizeSqFt      low  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031    -118.202558        5016   772977
# 1020 MONTECITO DR LOS ANGELES CA 90031    -118.203251        7648   737673
# 1072 MONTECITO DR LOS ANGELES CA 90031    -118.201981        5200   740497
# 1092 MONTECITO DR LOS ANGELES CA 90031    -118.201609        5200   892472
# 1196 MONTECITO DR LOS ANGELES CA 90031    -118.199365        3070   943497
# 1226 MONTECITO DR LOS ANGELES CA 90031    -118.198436        5924   703513
# 122 AVENUE 23 LOS ANGELES CA 90031        -118.217979       20000   656960
# 122 AVENUE 23 LOS ANGELES CA 90031        -118.217979       20000   656960
# 122 AVENUE 23 LOS ANGELES CA 90031        -118.217979       20000   656960
# 122 AVENUE 23 LOS ANGELES CA 90031        -118.217979       20000   656960
# 122 AVENUE 23 LOS ANGELES CA 90031        -118.217979       20000   656960
# 122 AVENUE 23 LOS ANGELES CA 90031        -118.217979       20000   656960
# 1331 MONTECITO CIR LOS ANGELES CA 90031   -118.198097        6540   669762
# 1414 MONTECITO DR LOS ANGELES CA 90031    -118.196554        7108   955307
# 1418 MONTECITO DR LOS ANGELES CA 90031    -118.196394        6511   769471
# 1430 MONTECITO DR LOS ANGELES CA 90031    -118.196137        4016   733730
# 148 AVENUE 25 LOS ANGELES CA 90031        -118.217316        4586   800690
# 1509 LANDA ST LOS ANGELES CA 90031        -118.244702        7143   635311
# 157 AVENUE 25 LOS ANGELES CA 90031        -118.217921        6449   734590
# 1936 THOMAS ST LOS ANGELES CA 90031       -118.204803        5622   964092
# 2125 VALLEJO ST LOS ANGELES CA 90031      -118.216612        7492   746293
# 2212 GATES ST LOS ANGELES CA 90031        -118.206246        2594   703851
# 2219 GLOVER PL LOS ANGELES CA 90031       -118.237619        3179   736205
# 2222 SICHEL ST LOS ANGELES CA 90031       -118.212659        8009  1168110
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031  -118.235677        5018  1139592
# 2230 OROS ST LOS ANGELES CA 90031         -118.228829        4174   661433
# 2237 SHOREDALE AVE LOS ANGELES CA 90031   -118.235075        5013   877106
# 223 AVENUE 38 LOS ANGELES CA 90031        -118.209529        7486   680789
# 2244 SHOREDALE AVE LOS ANGELES CA 90031   -118.234475        5000   893650
# 2253 ELMGROVE ST LOS ANGELES CA 90031     -118.231617        5096   859667
# ...                                               ...         ...      ...
# 4128 MERCURY AVE LOS ANGELES CA 90031     -118.196725        5294   675159
# 4130 MERCURY AVE LOS ANGELES CA 90031     -118.196639        5294   675210
# 4134 MERCURY AVE LOS ANGELES CA 90031     -118.196553        5293   687583
# 489 CLIFTON ST LOS ANGELES CA 90031       -118.207556        6011   807184
# 548 MONTECITO DR LOS ANGELES CA 90031     -118.201096        5244   932323
# 600 MONTECITO DR LOS ANGELES CA 90031     -118.199395        6258   841853
# 610 MONTECITO DR LOS ANGELES CA 90031     -118.198996        4660  1141946
# 629 AVENUE 28 LOS ANGELES CA 90031        -118.205403       42906      NaN
# 717 MONTECITO DR LOS ANGELES CA 90031     -118.198314        6616  1143346
# 734 AVENUE 43 LOS ANGELES CA 90031        -118.201678        4878   502685
# 749 AVENUE 43 LOS ANGELES CA 90031        -118.200956        5808   767942
# 749 MONTECITO DR LOS ANGELES CA 90031     -118.198387        6581   750861
# 755 MONTECITO DR LOS ANGELES CA 90031     -118.198717        4791   681669
# 757 AVENUE 43 LOS ANGELES CA 90031        -118.200741        4911   803822
# 759 MONTECITO DR LOS ANGELES CA 90031     -118.198861        5327   706640
# 763 MONTECITO DR LOS ANGELES CA 90031     -118.199013        6555   689254
# 767 MONTECITO DR LOS ANGELES CA 90031     -118.199135        4817   707998
# 771 MONTECITO DR LOS ANGELES CA 90031     -118.199238        4316   746045
# 775 MONTECITO DR LOS ANGELES CA 90031     -118.199348        3615   581315
# 781 MONTECITO DR LOS ANGELES CA 90031     -118.199498        4399   739841
# 782 MONTECITO DR LOS ANGELES CA 90031     -118.199639        4853   808486
# 834 MONTECITO DR LOS ANGELES CA 90031     -118.200363        6098   916842
# 846 MONTECITO DR LOS ANGELES CA 90031     -118.200033        4617   776955
# 888 MONTECITO DR LOS ANGELES CA 90031     -118.199478        3615   841126
# 905 MONTECITO DR LOS ANGELES CA 90031     -118.200015        4791   715312
# 906 MONTECITO DR LOS ANGELES CA 90031     -118.200077        5073   817278
# 909 MONTECITO DR LOS ANGELES CA 90031      -118.20014        4451   688822
# 913 MONTECITO DR LOS ANGELES CA 90031     -118.200266        4225   798568
# 937 MONTECITO DR LOS ANGELES CA 90031     -118.201061        3919   656032
# 969 MONTECITO DR LOS ANGELES CA 90031     -118.202356        7619   806468
#
#                                          percentile state  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031            0    CA
# 1020 MONTECITO DR LOS ANGELES CA 90031            0    CA
# 1072 MONTECITO DR LOS ANGELES CA 90031            0    CA
# 1092 MONTECITO DR LOS ANGELES CA 90031            0    CA
# 1196 MONTECITO DR LOS ANGELES CA 90031            0    CA
# 1226 MONTECITO DR LOS ANGELES CA 90031            0    CA
# 122 AVENUE 23 LOS ANGELES CA 90031                0    CA
# 122 AVENUE 23 LOS ANGELES CA 90031                0    CA
# 122 AVENUE 23 LOS ANGELES CA 90031                0    CA
# 122 AVENUE 23 LOS ANGELES CA 90031                0    CA
# 122 AVENUE 23 LOS ANGELES CA 90031                0    CA
# 122 AVENUE 23 LOS ANGELES CA 90031                0    CA
# 1331 MONTECITO CIR LOS ANGELES CA 90031           0    CA
# 1414 MONTECITO DR LOS ANGELES CA 90031            0    CA
# 1418 MONTECITO DR LOS ANGELES CA 90031            0    CA
# 1430 MONTECITO DR LOS ANGELES CA 90031            0    CA
# 148 AVENUE 25 LOS ANGELES CA 90031                0    CA
# 1509 LANDA ST LOS ANGELES CA 90031                0    CA
# 157 AVENUE 25 LOS ANGELES CA 90031                0    CA
# 1936 THOMAS ST LOS ANGELES CA 90031               0    CA
# 2125 VALLEJO ST LOS ANGELES CA 90031              0    CA
# 2212 GATES ST LOS ANGELES CA 90031                0    CA
# 2219 GLOVER PL LOS ANGELES CA 90031               0    CA
# 2222 SICHEL ST LOS ANGELES CA 90031               0    CA
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031          0    CA
# 2230 OROS ST LOS ANGELES CA 90031                 0    CA
# 2237 SHOREDALE AVE LOS ANGELES CA 90031           0    CA
# 223 AVENUE 38 LOS ANGELES CA 90031                0    CA
# 2244 SHOREDALE AVE LOS ANGELES CA 90031           0    CA
# 2253 ELMGROVE ST LOS ANGELES CA 90031             0    CA
# ...                                             ...   ...
# 4128 MERCURY AVE LOS ANGELES CA 90031             0    CA
# 4130 MERCURY AVE LOS ANGELES CA 90031             0    CA
# 4134 MERCURY AVE LOS ANGELES CA 90031             0    CA
# 489 CLIFTON ST LOS ANGELES CA 90031               0    CA
# 548 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 600 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 610 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 629 AVENUE 28 LOS ANGELES CA 90031                0    CA
# 717 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 734 AVENUE 43 LOS ANGELES CA 90031                0    CA
# 749 AVENUE 43 LOS ANGELES CA 90031                0    CA
# 749 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 755 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 757 AVENUE 43 LOS ANGELES CA 90031                0    CA
# 759 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 763 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 767 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 771 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 775 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 781 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 782 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 834 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 846 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 888 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 905 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 906 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 909 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 913 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 937 MONTECITO DR LOS ANGELES CA 90031             0    CA
# 969 MONTECITO DR LOS ANGELES CA 90031             0    CA
#
#                                                        street taxAssessment  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031      1007 Montecito Dr      417145.0
# 1020 MONTECITO DR LOS ANGELES CA 90031      1020 Montecito Dr      219621.0
# 1072 MONTECITO DR LOS ANGELES CA 90031      1072 Montecito Dr      325598.0
# 1092 MONTECITO DR LOS ANGELES CA 90031      1092 Montecito Dr      920754.0
# 1196 MONTECITO DR LOS ANGELES CA 90031      1196 Montecito Dr      420326.0
# 1226 MONTECITO DR LOS ANGELES CA 90031      1226 Montecito Dr      540908.0
# 122 AVENUE 23 LOS ANGELES CA 90031            122 N Avenue 23           NaN
# 122 AVENUE 23 LOS ANGELES CA 90031            122 N Avenue 23           NaN
# 122 AVENUE 23 LOS ANGELES CA 90031            122 N Avenue 23           NaN
# 122 AVENUE 23 LOS ANGELES CA 90031            122 N Avenue 23           NaN
# 122 AVENUE 23 LOS ANGELES CA 90031            122 N Avenue 23           NaN
# 122 AVENUE 23 LOS ANGELES CA 90031            122 N Avenue 23           NaN
# 1331 MONTECITO CIR LOS ANGELES CA 90031    1331 Montecito Cir      253524.0
# 1414 MONTECITO DR LOS ANGELES CA 90031      1414 Montecito Dr      365106.0
# 1418 MONTECITO DR LOS ANGELES CA 90031      1418 Montecito Dr      373370.0
# 1430 MONTECITO DR LOS ANGELES CA 90031      1430 Montecito Dr      747259.0
# 148 AVENUE 25 LOS ANGELES CA 90031            148 N Avenue 25      204037.0
# 1509 LANDA ST LOS ANGELES CA 90031              1509 Landa St      236127.0
# 157 AVENUE 25 LOS ANGELES CA 90031            157 N Avenue 25      299272.0
# 1936 THOMAS ST LOS ANGELES CA 90031            1936 Thomas St      133192.0
# 2125 VALLEJO ST LOS ANGELES CA 90031          2125 Vallejo St      604400.0
# 2212 GATES ST LOS ANGELES CA 90031              2212 Gates St      413960.0
# 2219 GLOVER PL LOS ANGELES CA 90031            2219 Glover Pl      395216.0
# 2222 SICHEL ST LOS ANGELES CA 90031            2222 Sichel St      562843.0
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031  2224 Meadowvale Ave      930000.0
# 2230 OROS ST LOS ANGELES CA 90031                2230 Oros St      258745.0
# 2237 SHOREDALE AVE LOS ANGELES CA 90031    2237 Shoredale Ave      584619.0
# 223 AVENUE 38 LOS ANGELES CA 90031            223 E Avenue 38      647335.0
# 2244 SHOREDALE AVE LOS ANGELES CA 90031    2244 Shoredale Ave      681533.0
# 2253 ELMGROVE ST LOS ANGELES CA 90031        2253 Elmgrove St      948600.0
# ...                                                       ...           ...
# 4128 MERCURY AVE LOS ANGELES CA 90031        4128 Mercury Ave      189095.0
# 4130 MERCURY AVE LOS ANGELES CA 90031        4130 Mercury Ave      199763.0
# 4134 MERCURY AVE LOS ANGELES CA 90031        4134 Mercury Ave      189095.0
# 489 CLIFTON ST LOS ANGELES CA 90031            489 Clifton St      481215.0
# 548 MONTECITO DR LOS ANGELES CA 90031        548 Montecito Dr      390038.0
# 600 MONTECITO DR LOS ANGELES CA 90031        600 Montecito Dr      259915.0
# 610 MONTECITO DR LOS ANGELES CA 90031        610 Montecito Dr      860615.0
# 629 AVENUE 28 LOS ANGELES CA 90031            629 E Avenue 28      636724.0
# 717 MONTECITO DR LOS ANGELES CA 90031        717 Montecito Dr      902025.0
# 734 AVENUE 43 LOS ANGELES CA 90031            734 E Avenue 43      673366.0
# 749 AVENUE 43 LOS ANGELES CA 90031            749 E Avenue 43      392786.0
# 749 MONTECITO DR LOS ANGELES CA 90031        749 Montecito Dr      778951.0
# 755 MONTECITO DR LOS ANGELES CA 90031        755 Montecito Dr      686664.0
# 757 AVENUE 43 LOS ANGELES CA 90031            757 E Avenue 43      354770.0
# 759 MONTECITO DR LOS ANGELES CA 90031        759 Montecito Dr      714000.0
# 763 MONTECITO DR LOS ANGELES CA 90031        763 Montecito Dr      733380.0
# 767 MONTECITO DR LOS ANGELES CA 90031        767 Montecito Dr      734400.0
# 771 MONTECITO DR LOS ANGELES CA 90031        771 Montecito Dr      707472.0
# 775 MONTECITO DR LOS ANGELES CA 90031        775 Montecito Dr      637500.0
# 781 MONTECITO DR LOS ANGELES CA 90031        781 Montecito Dr      423187.0
# 782 MONTECITO DR LOS ANGELES CA 90031        782 Montecito Dr      845580.0
# 834 MONTECITO DR LOS ANGELES CA 90031        834 Montecito Dr      738610.0
# 846 MONTECITO DR LOS ANGELES CA 90031        846 Montecito Dr      686600.0
# 888 MONTECITO DR LOS ANGELES CA 90031        888 Montecito Dr      599513.0
# 905 MONTECITO DR LOS ANGELES CA 90031        905 Montecito Dr      691865.0
# 906 MONTECITO DR LOS ANGELES CA 90031        906 Montecito Dr      142800.0
# 909 MONTECITO DR LOS ANGELES CA 90031        909 Montecito Dr      671057.0
# 913 MONTECITO DR LOS ANGELES CA 90031        913 Montecito Dr      569608.0
# 937 MONTECITO DR LOS ANGELES CA 90031        937 Montecito Dr      268969.0
# 969 MONTECITO DR LOS ANGELES CA 90031        969 Montecito Dr      399342.0
#
#                                          taxAssessmentYear totalRooms  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031                2019        NaN
# 1020 MONTECITO DR LOS ANGELES CA 90031                2019        NaN
# 1072 MONTECITO DR LOS ANGELES CA 90031                2019        NaN
# 1092 MONTECITO DR LOS ANGELES CA 90031                2019        NaN
# 1196 MONTECITO DR LOS ANGELES CA 90031                2019        NaN
# 1226 MONTECITO DR LOS ANGELES CA 90031                2019        NaN
# 122 AVENUE 23 LOS ANGELES CA 90031                     NaN          3
# 122 AVENUE 23 LOS ANGELES CA 90031                     NaN          3
# 122 AVENUE 23 LOS ANGELES CA 90031                     NaN          3
# 122 AVENUE 23 LOS ANGELES CA 90031                     NaN          3
# 122 AVENUE 23 LOS ANGELES CA 90031                     NaN          3
# 122 AVENUE 23 LOS ANGELES CA 90031                     NaN          3
# 1331 MONTECITO CIR LOS ANGELES CA 90031               2019        NaN
# 1414 MONTECITO DR LOS ANGELES CA 90031                2019        NaN
# 1418 MONTECITO DR LOS ANGELES CA 90031                2019        NaN
# 1430 MONTECITO DR LOS ANGELES CA 90031                2019        NaN
# 148 AVENUE 25 LOS ANGELES CA 90031                    2019        NaN
# 1509 LANDA ST LOS ANGELES CA 90031                    2019        NaN
# 157 AVENUE 25 LOS ANGELES CA 90031                    2019        NaN
# 1936 THOMAS ST LOS ANGELES CA 90031                   2019        NaN
# 2125 VALLEJO ST LOS ANGELES CA 90031                  2019          8
# 2212 GATES ST LOS ANGELES CA 90031                    2019        NaN
# 2219 GLOVER PL LOS ANGELES CA 90031                   2019        NaN
# 2222 SICHEL ST LOS ANGELES CA 90031                   2019        NaN
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031              2019          3
# 2230 OROS ST LOS ANGELES CA 90031                     2019        NaN
# 2237 SHOREDALE AVE LOS ANGELES CA 90031               2019        NaN
# 223 AVENUE 38 LOS ANGELES CA 90031                    2019          7
# 2244 SHOREDALE AVE LOS ANGELES CA 90031               2019        NaN
# 2253 ELMGROVE ST LOS ANGELES CA 90031                 2019          8
# ...                                                    ...        ...
# 4128 MERCURY AVE LOS ANGELES CA 90031                 2019        NaN
# 4130 MERCURY AVE LOS ANGELES CA 90031                 2019        NaN
# 4134 MERCURY AVE LOS ANGELES CA 90031                 2019        NaN
# 489 CLIFTON ST LOS ANGELES CA 90031                   2019        NaN
# 548 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 600 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 610 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 629 AVENUE 28 LOS ANGELES CA 90031                    2019        NaN
# 717 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 734 AVENUE 43 LOS ANGELES CA 90031                    2019        NaN
# 749 AVENUE 43 LOS ANGELES CA 90031                    2019        NaN
# 749 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 755 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 757 AVENUE 43 LOS ANGELES CA 90031                    2019        NaN
# 759 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 763 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 767 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 771 MONTECITO DR LOS ANGELES CA 90031                 2019          6
# 775 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 781 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 782 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 834 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 846 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 888 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 905 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 906 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 909 MONTECITO DR LOS ANGELES CA 90031                 2019          7
# 913 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 937 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
# 969 MONTECITO DR LOS ANGELES CA 90031                 2019        NaN
#
#                                                         useCode valueChange  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031             SingleFamily       25890
# 1020 MONTECITO DR LOS ANGELES CA 90031             SingleFamily       21416
# 1072 MONTECITO DR LOS ANGELES CA 90031             SingleFamily       16206
# 1092 MONTECITO DR LOS ANGELES CA 90031              Condominium        2286
# 1196 MONTECITO DR LOS ANGELES CA 90031             SingleFamily          68
# 1226 MONTECITO DR LOS ANGELES CA 90031             SingleFamily       -7486
# 122 AVENUE 23 LOS ANGELES CA 90031                    Townhouse       12429
# 122 AVENUE 23 LOS ANGELES CA 90031                    Townhouse       12429
# 122 AVENUE 23 LOS ANGELES CA 90031                    Townhouse       12429
# 122 AVENUE 23 LOS ANGELES CA 90031                    Townhouse       12429
# 122 AVENUE 23 LOS ANGELES CA 90031                    Townhouse       12429
# 122 AVENUE 23 LOS ANGELES CA 90031                    Townhouse       12429
# 1331 MONTECITO CIR LOS ANGELES CA 90031            SingleFamily      -14277
# 1414 MONTECITO DR LOS ANGELES CA 90031             SingleFamily      204975
# 1418 MONTECITO DR LOS ANGELES CA 90031             SingleFamily       30985
# 1430 MONTECITO DR LOS ANGELES CA 90031             SingleFamily        7501
# 148 AVENUE 25 LOS ANGELES CA 90031                 SingleFamily        9269
# 1509 LANDA ST LOS ANGELES CA 90031                 SingleFamily        5009
# 157 AVENUE 25 LOS ANGELES CA 90031                 SingleFamily        9228
# 1936 THOMAS ST LOS ANGELES CA 90031                SingleFamily        -247
# 2125 VALLEJO ST LOS ANGELES CA 90031               SingleFamily      -11841
# 2212 GATES ST LOS ANGELES CA 90031                 SingleFamily        8794
# 2219 GLOVER PL LOS ANGELES CA 90031                SingleFamily        1260
# 2222 SICHEL ST LOS ANGELES CA 90031                SingleFamily       22936
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031           SingleFamily       45068
# 2230 OROS ST LOS ANGELES CA 90031                  SingleFamily       -3889
# 2237 SHOREDALE AVE LOS ANGELES CA 90031            SingleFamily       15666
# 223 AVENUE 38 LOS ANGELES CA 90031                 SingleFamily       -1115
# 2244 SHOREDALE AVE LOS ANGELES CA 90031            SingleFamily       39742
# 2253 ELMGROVE ST LOS ANGELES CA 90031              SingleFamily        2080
# ...                                                         ...         ...
# 4128 MERCURY AVE LOS ANGELES CA 90031              SingleFamily       -9832
# 4130 MERCURY AVE LOS ANGELES CA 90031              SingleFamily       -9722
# 4134 MERCURY AVE LOS ANGELES CA 90031              SingleFamily       -7829
# 489 CLIFTON ST LOS ANGELES CA 90031                SingleFamily       23059
# 548 MONTECITO DR LOS ANGELES CA 90031              SingleFamily       27333
# 600 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        1850
# 610 MONTECITO DR LOS ANGELES CA 90031              SingleFamily       -3870
# 629 AVENUE 28 LOS ANGELES CA 90031        VacantResidentialLand         NaN
# 717 MONTECITO DR LOS ANGELES CA 90031              SingleFamily       23360
# 734 AVENUE 43 LOS ANGELES CA 90031                  Condominium        3783
# 749 AVENUE 43 LOS ANGELES CA 90031                 SingleFamily       24571
# 749 MONTECITO DR LOS ANGELES CA 90031              SingleFamily       10457
# 755 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        3772
# 757 AVENUE 43 LOS ANGELES CA 90031                 SingleFamily       14648
# 759 MONTECITO DR LOS ANGELES CA 90031           MultiFamily2To4        4091
# 763 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        1864
# 767 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        1481
# 771 MONTECITO DR LOS ANGELES CA 90031              SingleFamily       24195
# 775 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        1707
# 781 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        4614
# 782 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        1817
# 834 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        3117
# 846 MONTECITO DR LOS ANGELES CA 90031              SingleFamily       25712
# 888 MONTECITO DR LOS ANGELES CA 90031              SingleFamily         620
# 905 MONTECITO DR LOS ANGELES CA 90031              SingleFamily       21860
# 906 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        2168
# 909 MONTECITO DR LOS ANGELES CA 90031              SingleFamily       -7783
# 913 MONTECITO DR LOS ANGELES CA 90031              SingleFamily        6572
# 937 MONTECITO DR LOS ANGELES CA 90031              SingleFamily      -16269
# 969 MONTECITO DR LOS ANGELES CA 90031              SingleFamily       17942
#
#                                          yearBuilt zindexValue zipcode  \
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031        2002     535,500   90031
# 1020 MONTECITO DR LOS ANGELES CA 90031        1991     535,500   90031
# 1072 MONTECITO DR LOS ANGELES CA 90031        2017     535,500   90031
# 1092 MONTECITO DR LOS ANGELES CA 90031        1965     535,500   90031
# 1196 MONTECITO DR LOS ANGELES CA 90031        2006     535,500   90031
# 1226 MONTECITO DR LOS ANGELES CA 90031        1993     535,500   90031
# 122 AVENUE 23 LOS ANGELES CA 90031            2008     489,200   90031
# 122 AVENUE 23 LOS ANGELES CA 90031            2008     489,200   90031
# 122 AVENUE 23 LOS ANGELES CA 90031            2008     489,200   90031
# 122 AVENUE 23 LOS ANGELES CA 90031            2008     489,200   90031
# 122 AVENUE 23 LOS ANGELES CA 90031            2008     489,200   90031
# 122 AVENUE 23 LOS ANGELES CA 90031            2008     489,200   90031
# 1331 MONTECITO CIR LOS ANGELES CA 90031       1994     535,500   90031
# 1414 MONTECITO DR LOS ANGELES CA 90031        1999     535,500   90031
# 1418 MONTECITO DR LOS ANGELES CA 90031        1999     535,500   90031
# 1430 MONTECITO DR LOS ANGELES CA 90031        2009     535,500   90031
# 148 AVENUE 25 LOS ANGELES CA 90031            1995     489,200   90031
# 1509 LANDA ST LOS ANGELES CA 90031            2018     809,300   90031
# 157 AVENUE 25 LOS ANGELES CA 90031            2006     489,200   90031
# 1936 THOMAS ST LOS ANGELES CA 90031           1991     489,200   90031
# 2125 VALLEJO ST LOS ANGELES CA 90031          1880     489,200   90031
# 2212 GATES ST LOS ANGELES CA 90031            1993     489,200   90031
# 2219 GLOVER PL LOS ANGELES CA 90031           2002     567,000   90031
# 2222 SICHEL ST LOS ANGELES CA 90031           2007     489,200   90031
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031      1940     567,000   90031
# 2230 OROS ST LOS ANGELES CA 90031             2013     567,000   90031
# 2237 SHOREDALE AVE LOS ANGELES CA 90031       1996     567,000   90031
# 223 AVENUE 38 LOS ANGELES CA 90031            1905     745,100   90031
# 2244 SHOREDALE AVE LOS ANGELES CA 90031       1927     567,000   90031
# 2253 ELMGROVE ST LOS ANGELES CA 90031         2018     567,000   90031
# ...                                            ...         ...     ...
# 4128 MERCURY AVE LOS ANGELES CA 90031         1998     535,500   90031
# 4130 MERCURY AVE LOS ANGELES CA 90031         1998     535,500   90031
# 4134 MERCURY AVE LOS ANGELES CA 90031         1998     535,500   90031
# 489 CLIFTON ST LOS ANGELES CA 90031           2006     489,200   90031
# 548 MONTECITO DR LOS ANGELES CA 90031         1992     535,500   90031
# 600 MONTECITO DR LOS ANGELES CA 90031         1998     535,500   90031
# 610 MONTECITO DR LOS ANGELES CA 90031         2004     535,500   90031
# 629 AVENUE 28 LOS ANGELES CA 90031            2016     489,200   90031
# 717 MONTECITO DR LOS ANGELES CA 90031         2005     535,500   90031
# 734 AVENUE 43 LOS ANGELES CA 90031            1910     535,500   90031
# 749 AVENUE 43 LOS ANGELES CA 90031            2009     535,500   90031
# 749 MONTECITO DR LOS ANGELES CA 90031         2007     535,500   90031
# 755 MONTECITO DR LOS ANGELES CA 90031         2007     535,500   90031
# 757 AVENUE 43 LOS ANGELES CA 90031            1997     535,500   90031
# 759 MONTECITO DR LOS ANGELES CA 90031         2007     535,500   90031
# 763 MONTECITO DR LOS ANGELES CA 90031         2007     535,500   90031
# 767 MONTECITO DR LOS ANGELES CA 90031         2007     535,500   90031
# 771 MONTECITO DR LOS ANGELES CA 90031         2007     535,500   90031
# 775 MONTECITO DR LOS ANGELES CA 90031         2007     535,500   90031
# 781 MONTECITO DR LOS ANGELES CA 90031         2007     535,500   90031
# 782 MONTECITO DR LOS ANGELES CA 90031         2003     535,500   90031
# 834 MONTECITO DR LOS ANGELES CA 90031         1978     535,500   90031
# 846 MONTECITO DR LOS ANGELES CA 90031         2005     535,500   90031
# 888 MONTECITO DR LOS ANGELES CA 90031         2005     535,500   90031
# 905 MONTECITO DR LOS ANGELES CA 90031         2009     535,500   90031
# 906 MONTECITO DR LOS ANGELES CA 90031         1995     535,500   90031
# 909 MONTECITO DR LOS ANGELES CA 90031         2008     535,500   90031
# 913 MONTECITO DR LOS ANGELES CA 90031         2008     535,500   90031
# 937 MONTECITO DR LOS ANGELES CA 90031         2001     535,500   90031
# 969 MONTECITO DR LOS ANGELES CA 90031         1954     535,500   90031
#
#                                                 zpid
# Full_Address
# 1007 MONTECITO DR LOS ANGELES CA 90031      20689097
# 1020 MONTECITO DR LOS ANGELES CA 90031      20689074
# 1072 MONTECITO DR LOS ANGELES CA 90031      20689138
# 1092 MONTECITO DR LOS ANGELES CA 90031      20689133
# 1196 MONTECITO DR LOS ANGELES CA 90031      82872725
# 1226 MONTECITO DR LOS ANGELES CA 90031      20689168
# 122 AVENUE 23 LOS ANGELES CA 90031        2112800844
# 122 AVENUE 23 LOS ANGELES CA 90031        2112800844
# 122 AVENUE 23 LOS ANGELES CA 90031        2112800844
# 122 AVENUE 23 LOS ANGELES CA 90031        2112800844
# 122 AVENUE 23 LOS ANGELES CA 90031        2112800844
# 122 AVENUE 23 LOS ANGELES CA 90031        2112800844
# 1331 MONTECITO CIR LOS ANGELES CA 90031     20689230
# 1414 MONTECITO DR LOS ANGELES CA 90031      20689340
# 1418 MONTECITO DR LOS ANGELES CA 90031      20689339
# 1430 MONTECITO DR LOS ANGELES CA 90031      95691502
# 148 AVENUE 25 LOS ANGELES CA 90031          20636609
# 1509 LANDA ST LOS ANGELES CA 90031          20754026
# 157 AVENUE 25 LOS ANGELES CA 90031          20636630
# 1936 THOMAS ST LOS ANGELES CA 90031         95633643
# 2125 VALLEJO ST LOS ANGELES CA 90031        20636216
# 2212 GATES ST LOS ANGELES CA 90031          20638653
# 2219 GLOVER PL LOS ANGELES CA 90031         20754815
# 2222 SICHEL ST LOS ANGELES CA 90031         20636367
# 2224 MEADOWVALE AVE LOS ANGELES CA 90031    20754764
# 2230 OROS ST LOS ANGELES CA 90031           68991805
# 2237 SHOREDALE AVE LOS ANGELES CA 90031     20754727
# 223 AVENUE 38 LOS ANGELES CA 90031          20755395
# 2244 SHOREDALE AVE LOS ANGELES CA 90031     20754709
# 2253 ELMGROVE ST LOS ANGELES CA 90031       20754657
# ...                                              ...
# 4128 MERCURY AVE LOS ANGELES CA 90031       20689527
# 4130 MERCURY AVE LOS ANGELES CA 90031       20689526
# 4134 MERCURY AVE LOS ANGELES CA 90031       20689525
# 489 CLIFTON ST LOS ANGELES CA 90031         68978606
# 548 MONTECITO DR LOS ANGELES CA 90031       20688894
# 600 MONTECITO DR LOS ANGELES CA 90031       20688997
# 610 MONTECITO DR LOS ANGELES CA 90031       20688991
# 629 AVENUE 28 LOS ANGELES CA 90031          95607090
# 717 MONTECITO DR LOS ANGELES CA 90031       68978634
# 734 AVENUE 43 LOS ANGELES CA 90031          20637232
# 749 AVENUE 43 LOS ANGELES CA 90031          95616428
# 749 MONTECITO DR LOS ANGELES CA 90031       82881734
# 755 MONTECITO DR LOS ANGELES CA 90031       79484427
# 757 AVENUE 43 LOS ANGELES CA 90031          20689031
# 759 MONTECITO DR LOS ANGELES CA 90031       79484428
# 763 MONTECITO DR LOS ANGELES CA 90031       79484429
# 767 MONTECITO DR LOS ANGELES CA 90031       79484430
# 771 MONTECITO DR LOS ANGELES CA 90031       79530458
# 775 MONTECITO DR LOS ANGELES CA 90031       79484431
# 781 MONTECITO DR LOS ANGELES CA 90031       79530459
# 782 MONTECITO DR LOS ANGELES CA 90031       20689012
# 834 MONTECITO DR LOS ANGELES CA 90031       20689043
# 846 MONTECITO DR LOS ANGELES CA 90031       68978633
# 888 MONTECITO DR LOS ANGELES CA 90031       68978632
# 905 MONTECITO DR LOS ANGELES CA 90031       89134156
# 906 MONTECITO DR LOS ANGELES CA 90031       95669657
# 909 MONTECITO DR LOS ANGELES CA 90031       95605561
# 913 MONTECITO DR LOS ANGELES CA 90031       95693278
# 937 MONTECITO DR LOS ANGELES CA 90031       20689188
# 969 MONTECITO DR LOS ANGELES CA 90031       20689117
#
# [442 rows x 27 columns]

# %%
#pd.DataFrame(data=[j.values() for i in Main_List for j in i.values()])
#pd.DataFrame(data=[j.values() for i in Main_List for j in i.values()],columns=[j.keys() for i in Main_List for j in i.values()])
# Out:
#             0                    1      2            3   4          5   \
# 0     20689097    1007 Montecito Dr  90031  Los Angeles  CA  34.087739
# 1     20689074    1020 Montecito Dr  90031  Los Angeles  CA  34.087427
# 2     20689138    1072 Montecito Dr  90031  Los Angeles  CA  34.086643
# 3     20689133    1092 Montecito Dr  90031  Los Angeles  CA  34.087098
# 4     82872725    1196 Montecito Dr  90031  Los Angeles  CA  34.087526
# 5     20689168    1226 Montecito Dr  90031  Los Angeles  CA  34.087346
# 6   2112800844      122 N Avenue 23  90031  Los Angeles  CA  34.076503
# 7   2112800844      122 N Avenue 23  90031  Los Angeles  CA  34.076503
# 8   2112800844      122 N Avenue 23  90031  Los Angeles  CA  34.076503
# 9   2112800844      122 N Avenue 23  90031  Los Angeles  CA  34.076503
# 10  2112800844      122 N Avenue 23  90031  Los Angeles  CA  34.076503
# 11  2112800844      122 N Avenue 23  90031  Los Angeles  CA  34.076503
# 12    20689230   1331 Montecito Cir  90031  Los Angeles  CA  34.088763
# 13    20689340    1414 Montecito Dr  90031  Los Angeles  CA  34.089263
# 14    20689339    1418 Montecito Dr  90031  Los Angeles  CA  34.089385
# 15    95691502    1430 Montecito Dr  90031  Los angeles  CA  34.089878
# 16    20636609      148 N Avenue 25  90031  Los Angeles  CA  34.077524
# 17    20754026        1509 Landa St  90031  Los Angeles  CA  34.094775
# 18    20636630      157 N Avenue 25  90031  Los Angeles  CA  34.077509
# 19    95633643       1936 Thomas St  90031  Los angeles  CA    34.0679
# 20    20636216      2125 Vallejo St  90031  Los Angeles  CA  34.071049
# 21    20638653        2212 Gates St  90031  Los Angeles  CA  34.070674
# 22    20754815       2219 Glover Pl  90031  Los Angeles  CA  34.090073
# 23    20636367       2222 Sichel St  90031  Los Angeles  CA   34.07088
# 24    20754764  2224 Meadowvale Ave  90031  Los Angeles  CA  34.088714
#
#              6          7             8      9         10    11    12  \
# 0   -118.202558       6037  SingleFamily   2019  417145.0  2002  5016
# 1   -118.203251       6037  SingleFamily   2019  219621.0  1991  7648
# 2   -118.201981       6037  SingleFamily   2019  325598.0  2017  5200
# 3   -118.201609       6037   Condominium   2019  920754.0  1965  5200
# 4   -118.199365       6037  SingleFamily   2019  420326.0  2006  3070
# 5   -118.198436       6037  SingleFamily   2019  540908.0  1993  5924
# 6   -118.217979  Townhouse          2008  20000      1650   2.5     3
# 7   -118.217979  Townhouse          2008  20000      1650   2.5     3
# 8   -118.217979  Townhouse          2008  20000      1650   2.5     3
# 9   -118.217979  Townhouse          2008  20000      1650   2.5     3
# 10  -118.217979  Townhouse          2008  20000      1650   2.5     3
# 11  -118.217979  Townhouse          2008  20000      1650   2.5     3
# 12  -118.198097       6037  SingleFamily   2019  253524.0  1994  6540
# 13  -118.196554       6037  SingleFamily   2019  365106.0  1999  7108
# 14  -118.196394       6037  SingleFamily   2019  373370.0  1999  6511
# 15  -118.196137       6037  SingleFamily   2019  747259.0  4016     3
# 16  -118.217316       6037  SingleFamily   2019  204037.0  1995  4586
# 17  -118.244702       6037  SingleFamily   2019  236127.0  2018  7143
# 18  -118.217921       6037  SingleFamily   2019  299272.0  2006  6449
# 19  -118.204803       6037  SingleFamily   2019  133192.0  1991  5622
# 20  -118.216612       6037  SingleFamily   2019  604400.0  1880  7492
# 21  -118.206246       6037  SingleFamily   2019  413960.0  1993  2594
# 22  -118.237619       6037  SingleFamily   2019  395216.0  2002  3179
# 23  -118.212659       6037  SingleFamily   2019  562843.0  2007  8009
# 24  -118.235677       6037  SingleFamily   2019  930000.0  1940  5018
#
#             13      14          15          16          17       18  \
# 0         1844     3.0           3  11/06/2001      315000   822316
# 1         1822     2.0           3      801818  10/26/2019    21416
# 2         2068     3.0           3  11/12/2014       90000   804888
# 3         1581     3.0           4  05/05/2017      885000   991635
# 4         1850     2.0           2      993155  10/26/2019       68
# 5         1471     3.0           3  05/31/2013      490000   764688
# 6            3  738157  10/26/2019       12429      656960   797210
# 7            3  738157  10/26/2019       12429      656960   797210
# 8            3  738157  10/26/2019       12429      656960   797210
# 9            3  738157  10/26/2019       12429      656960   797210
# 10           3  738157  10/26/2019       12429      656960   797210
# 11           3  738157  10/26/2019       12429      656960   797210
# 12        1292     2.0           2      728002  10/26/2019   -14277
# 13        1767     3.0           3  12/23/1999      265000  1005586
# 14        1869     3.0           3  12/17/1999      273000   827388
# 15  10/26/2019       0     535,500        2009        1814      3.0
# 16        2210     3.0           4      851798  10/26/2019     9269
# 17         447     1.0           1  06/06/2006      125000   698144
# 18        1651     2.0           3      798467  10/26/2019     9228
# 19        3360     4.0           3     1071213  01/01/1970     -247
# 20        2475     3.0           4           8  06/28/2014   550000
# 21        2016     3.0           5  07/24/2003      185000   756829
# 22        1680     3.0           4  06/04/2019      800000   809017
# 23        4572     4.0           6  08/05/2004      140000  1327398
# 24        2110     3.0           4           3  09/20/2019  1250000
#
#             19          20       21       22       23       24       25
# 0   10/26/2019       25890   772977   871655        0  535,500     None
# 1       737673      857945        0  535,500     None     None     None
# 2   10/26/2019       16206   740497   869279        0  535,500     None
# 3   10/26/2019        2286   892472  1110631        0  535,500     None
# 4       943497     1042813        0  535,500     None     None     None
# 5   10/26/2019       -7486   703513   833510        0  535,500     None
# 6            0     489,200     None     None     None     None     None
# 7            0     489,200     None     None     None     None     None
# 8            0     489,200     None     None     None     None     None
# 9            0     489,200     None     None     None     None     None
# 10           0     489,200     None     None     None     None     None
# 11           0     489,200     None     None     None     None     None
# 12      669762      778962        0  535,500     None     None     None
# 13  10/26/2019      204975   955307  1065921        0  535,500     None
# 14  10/26/2019       30985   769471   885305        0  535,500     None
# 15  05/19/2014      695000   788957     7501   733730   852074     None
# 16      800690      911424        0  489,200     None     None     None
# 17  10/26/2019        5009   635311   767958        0  809,300     None
# 18      734590      870329        0  489,200     None     None     None
# 19      964092     1199759        0  489,200     None     None     None
# 20      867783  10/26/2019   -11841   746293  1032662        0  489,200
# 21  10/26/2019        8794   703851   809807        0  489,200     None
# 22  10/26/2019        1260   736205   889919        0  567,000     None
# 23  10/26/2019       22936  1168110  1553056        0  489,200     None
# 24     1252299  10/26/2019    45068  1139592  1377529        0  567,000
